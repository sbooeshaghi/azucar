# %% [markdown]
# <a href="https://colab.research.google.com/github/sbooeshaghi/azucar/blob/main/analysis/brain/obs7/annotate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --quiet kb_python scanpy numba leidenalg 
# !apt-get -qq install nvidia-cuda-toolkit
# Out:
# E: Unmet dependencies. Try 'apt --fix-broken install' with no packages (or specify a solution).

# %%
# !git clone https://github.com/sbooeshaghi/azucar.git
# Out:
# Cloning into 'azucar'...
# remote: Enumerating objects: 1106, done.
# remote: Counting objects: 100% (547/547), done.
# remote: Compressing objects: 100% (468/468), done.
# remote: Total 1106 (delta 176), reused 267 (delta 68), pack-reused 559
# Receiving objects: 100% (1106/1106), 1.61 GiB | 34.13 MiB/s, done.
# Resolving deltas: 100% (398/398), done.
# Checking out files: 100% (284/284), done.

# %%
#@title import
import os
import sys
import matplotlib.pyplot as plt
from sklearn.metrics import rand_score
from mpl_toolkits.axes_grid1 import make_axes_locatable
import json
import pandas as pd
import numpy as np
import scanpy as sc
from sklearn.decomposition import PCA
from collections import defaultdict
from scipy.io import mmread, mmwrite
from scipy.sparse import csr_matrix
from sklearn.neighbors import KDTree
from scipy.stats import entropy, pearsonr
from itertools import combinations
from kb_python.utils import import_matrix_as_anndata
from mpl_toolkits.axes_grid1 import make_axes_locatable


def nd(arr):
    return np.asarray(arr).reshape(-1)

def yex(ax):
    lims = [
        np.min([ax.get_xlim(), ax.get_ylim()]),  # min of both axes
        np.max([ax.get_xlim(), ax.get_ylim()]),  # max of both axes
    ]

    # now plot both limits against eachother
    ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
    ax.set_aspect('equal')
    ax.set_xlim(lims)
    ax.set_ylim(lims)
    return ax

fsize=20

plt.rcParams.update({'font.size': fsize})
# %config InlineBackend.figure_format = 'retina'

# %%
sample = "brain"
observation = "obs7"

base_data = f"azucar/analysis/{sample}/{observation}/out"
base_mark = f"azucar/analysis/{sample}/{observation}/assign"
base_ref  = f"azucar/reference/{sample}/cdna"

# path for assignments
asn_obs = "obs8"
base_asn = f"azucar/analysis/{sample}/{asn_obs}/assign"
asn_fn = os.path.join(base_asn, "assignments.txt")

markers_fn = os.path.join(base_mark, "markers.txt")
matrix_fn  = os.path.join(base_data, "matrix.mtx")
genes_fn   = os.path.join(base_data, "genes.txt")
barcodes_fn   = os.path.join(base_data, "barcodes.txt")

t2g_fn = os.path.join(base_ref, "t2g.txt")

# %%
# !gunzip $base_data/*.gz
# !gunzip $base_asn/*.gz
# Out:
# gzip: azucar/analysis/brain/obs7/out/*.gz: No such file or directory
# gzip: azucar/analysis/brain/obs8/assign/*.gz: No such file or directory

# %%
# load cdna
adata = import_matrix_as_anndata(matrix_path=matrix_fn, barcodes_path=barcodes_fn, genes_path=genes_fn)

# load assignments
assignments = pd.read_csv(asn_fn, sep="\t", index_col=0)
cols = assignments.columns.values

# map data from assignments to cdna
for i in cols:
  adata.obs[i] = adata.obs.index.map(assignments[i])

# map gene name to cdna
t2g = pd.read_csv(t2g_fn, 
                  header = None, 
                  names=["tid", "gid", "gene", "transcript", "chrom", "start", "stop", "strand"], 
                  sep="\t")
t2g = t2g.drop_duplicates("gid")
t2g = t2g.set_index("gid")

# map gene names to gene
adata.var["gene"] = adata.var.index.map(t2g["gene"])
adata.var["gene_gid"] = adata.var.gene + '_' + adata.var.index
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 16016 × 55416
#     obs: 'mtag3_ipf', 'mtag4_ipf', 'mtag1_ipf', 'mtag2_ipf', 'dbco_ipf', 'mtag1', 'mtag2', 'mtag3', 'mtag4', 'dbco', 'label_id', 'label', 'ent', 'mahalanobis_0', 'mahalanobis_1', 'mahalanobis_2', 'mahalanobis_3'
#     var: 'gene', 'gene_gid'

# %%
# preprocessing
adata.layers["log1p"] = np.log1p(adata.X)

# TODO figure out why we have nan genes
adata = adata[:,adata.var.notna()["gene"]].copy()

# drop ribosomal and mitochondrial genes
dropgenes = np.logical_and(
    np.logical_and(
        ~adata.var.gene.str.upper().str.contains("RPL").values, 
        ~adata.var.gene.str.upper().str.startswith("MT-").values), 
    adata.var.gene.str.upper() != "MALAT1")
adata = adata[:,dropgenes].copy()

# drop the cells without assignments
adata = adata[adata.obs.notna()["label"]].copy()

adata
# Out:
# AnnData object with n_obs × n_vars = 7511 × 53580
#     obs: 'mtag3_ipf', 'mtag4_ipf', 'mtag1_ipf', 'mtag2_ipf', 'dbco_ipf', 'mtag1', 'mtag2', 'mtag3', 'mtag4', 'dbco', 'label_id', 'label', 'ent', 'mahalanobis_0', 'mahalanobis_1', 'mahalanobis_2', 'mahalanobis_3'
#     var: 'gene', 'gene_gid'
#     layers: 'log1p'

# %%
conditions = np.unique(adata.obs.label.values)

data = {}
for c in conditions:
  data[c] = adata[adata.obs.eval(f"label == '{c}'").values].copy()

# %%
# gene cutoffs
fig, ax = plt.subplots(figsize=(5,5))
ng = []
co = []
for label, a in data.items():
    x = np.sort(nd(a.X.sum(0)))[::-1]
    y = np.arange(x.shape[0])

    # if you return the entropy, you can pass it here as a color
    ax.scatter(x,y, label=label)

    cutoff = 100
    top_g = 1000
    ngenes = np.where(x>cutoff)[0][-1]
    ng_cutoff = x[:top_g][-1]
    co.append(ng_cutoff)
    ng.append(ngenes)
    ax.axvline(x=cutoff, color='k')
    ax.axhline(y=ngenes, color='k')

ax.set(**{
    "yscale" : "symlog",
    "xscale": "symlog",
    "xlim": 0,
    "ylim": 0

})
ax.legend(bbox_to_anchor=(1,1), loc="upper left")
fig.show()

# %%
# actually do the cutoff on genes and log1p that dude
for idx, ((l, i), c) in enumerate(zip(data.items(), co)):
    data[l] = i[:,i.X.sum(0) > c].copy()
    data[l].layers["raw"] = data[l].X.copy()
    data[l].X = data[l].layers["log1p"].copy()

# %%
# neighrborhood graph then clustering then tsne
for idx, (_, i) in enumerate(data.items()):
    sc.pp.neighbors(i, use_rep="X")
    sc.tl.leiden(i)
    sc.tl.tsne(i, use_rep="X")
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,

# %%
for idx, (l, i) in enumerate(data.items()):
    print(i.obs.leiden.value_counts())
# Out:
# 0     1059
# 1      751
# 2      518
# 3      471
# 4      296
# 5      281
# 6      263
# 7      187
# 8      186
# 9      174
# 10      66
# 11      24
# Name: leiden, dtype: int64
# 0     378
# 1     314
# 2     294
# 3     283
# 4     221
# 5     184
# 6     169
# 7     166
# 8     156
# 9      82
# 10     67
# 11     16
# Name: leiden, dtype: int64
# 0    100
# 1     92
# 2     83
# 3     72
# 4     23
# 5     20
# 6     17
# 7      8
# Name: leiden, dtype: int64
# 0    103
# 1     88
# 2     83
# 3     59
# 4     54
# 5     41
# 7     31
# 6     31
# Name: leiden, dtype: int64

# %%
fig, axs = plt.subplots(figsize=(20, 5), ncols=len(data.keys()))

for idx, ((l, i), ax) in enumerate(zip(data.items(), axs)):
    x = i.obsm["X_tsne"][:,0]
    y = i.obsm["X_tsne"][:,1]
    c = i.obs.leiden.values.astype(int)
    ax.scatter(x,y, c=c, cmap="tab20c")
    ax.set(**{
        "title": l
    })

    ax.set_axis_off()
fig.show()

# %%
#@title dexpress

from scipy.stats import ks_2samp, ttest_ind
import numpy as np
import pandas as pd
import logging

logger = logging.getLogger()
logger.setLevel(logging.INFO)
logging.basicConfig(format='%(asctime)s - %(message)s', datefmt='%d-%b-%y %H:%M:%S')

import numpy as np
from statsmodels.stats.multitest import multipletests

def split_by_target(mat, targets, target, axis=0):
    """
    Split the rows of mat by the proper assignment
    
    mat = ndarray
    targets, length is equal to number of components (axis=0) or features (axis=1)
    target is a singular element from unique(assignments/features) 
    """
    if axis==0 and len(targets) != mat.shape[axis]: return -1
    if axis==1 and len(targets) != mat.shape[axis]: return -1
        
    mask = targets == target
    
    if axis==0:
        t_mat = mat[mask]  # target matrix
        c_mat = mat[~mask] # complement matrix
    elif axis==1:
        t_mat = mat[:, mask]  # target matrix
        c_mat = mat[:, ~mask] # complement matrix
    
    return (t_mat, c_mat)

def correct_pval(pval, nfeat, method):
    if method == 'bonferroni':
        pval_corr = np.minimum(pval*nfeat[:,None], 1.0)
    return pval_corr

def nd(arr):
    return np.asarray(arr).reshape(-1)
def correct_pvals(pvals):
    r = np.empty(np.shape(pvals))
    r[:] = np.nan
    for pidx, p in enumerate(pvals):
        mask = ~np.isnan(p)


    return r


def dexpress(mat, components, features, assignments, **kwargs):
    """
    mat: ndarray
    components: nparray
    features: nparray
    assignments: nparray, length is equal to length of components
    """
    nan_cutoff = kwargs.get("nan_cutoff", 0)
    
    unique = np.unique(assignments)
        
    ncomp = components.shape[0]
    nfeat = features.shape[0]
    nuniq = unique.shape[0]
    
    pval = np.empty((nuniq, nfeat)) # unique assignments by features 
    pval_corr = np.empty((nuniq, nfeat)) # unique assignments by features 
    stat = np.empty((nuniq, nfeat)) # unique assignments by features 
    es = np.empty((nuniq, nfeat)) # unique assignments by features 
    nfeatures = np.empty((nuniq))
    
    pval.fill(np.nan)
    pval_corr.fill(np.nan)
    stat.fill(np.nan)
    es.fill(np.nan)
    nfeatures.fill(np.nan)
    

    for tidx, t in enumerate(unique):
        logging.info("{} of {} assignments: {}".format(tidx+1, nuniq, t))
        t_mat, c_mat = split_by_target(mat, assignments, t, axis=0)
        
        pvalue = np.nan
        statistic = np.nan
        effect_size = np.nan

        # Keep only the genes for which it is in at least nan_cutoff*ncellsinclusters
        mask = np.asarray((t_mat>0).sum(axis=0) > nan_cutoff*t_mat.shape[0]).reshape(-1)

        t_mat = t_mat[:, mask]
        c_mat = c_mat[:, mask]
        # added

        # added
        if mask.sum()>0:
            test = ttest_ind(t_mat, c_mat, nan_policy="propagate", equal_var=False)
            pvalue = test.pvalue
            statistic = test.statistic
            effect_size = nd(t_mat.mean(axis=0)) - nd(c_mat.mean(axis=0))
            nfeatures[tidx] = mask.sum()
                
        pval[tidx,:][mask] = pvalue
        stat[tidx,:][mask] = statistic
        es[tidx,:][mask] = effect_size
    return (pval, stat, es, nfeatures)

def make_table(assignments, features, p_raw, p_corr, es):
    unique = np.unique(assignments)
    markers = pd.DataFrame(index=unique, columns=["gene", "p_raw", "p_corr", "es"])

    for uidx, u in enumerate(unique):
        markers.loc[u]["gene"] = features
        markers.loc[u]["p_raw"] = p_raw[uidx]
        markers.loc[u]["p_corr"] = p_corr[uidx]
        markers.loc[u]["es"] = es[uidx]

    markers = markers.apply(pd.Series.explode).reset_index()
    markers = markers[markers.notnull()["p_raw"]]
    markers = markers.rename(columns={"index": "group_id"})
    return markers
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ## Marker genes per condition

# %%
# %%time
# compare gene expression between conditions (ignoring celltype)
mat           = adata.layers["log1p"].toarray() # this is log1p
components    = adata.obs.index.values
features      = adata.var.gene_gid.values
assignments   = adata.obs.label.values # this is condition


unique = np.unique(assignments)
nan_cutoff = 0.9 # of elements in cluster
corr_method = "bonferroni"


p_raw, stat, es, nfeat = dexpress(mat, components, features, assignments, nan_cutoff=nan_cutoff)
p_raw = p_raw/2
p_corr = correct_pval(p_raw, nfeat, corr_method)

s = stat

df = make_table(assignments, features, p_raw, p_corr, es)

# convert the 0 pvalues to the smallest possible float
df["p_corr"][df.eval("p_corr == 0").values] = sys.float_info.min
df = df.query("p_corr < 0.05")
# Out:
# 27-Jan-22 20:42:51 - 1 of 4 assignments: bic
# 27-Jan-22 20:42:54 - 2 of 4 assignments: bic_tmg
# 27-Jan-22 20:42:55 - 3 of 4 assignments: control
# 27-Jan-22 20:42:56 - 4 of 4 assignments: tmg
# CPU times: user 4.51 s, sys: 2.18 s, total: 6.69 s
# Wall time: 7.62 s

# %%
df.group_id.value_counts()
# Out:
# control    215
# tmg         20
# bic          6
# bic_tmg      6
# Name: group_id, dtype: int64

# %%
df.sort_values('es', ascending = False)
# Out:
#        group_id                          gene  ...        p_corr        es
# 119777  control   Rps3a3_ENSMUSG00000059751.8  ...  1.08222e-117   2.61605
# 154077  control  Eef1a1_ENSMUSG00000037742.15  ...  1.84558e-144     2.339
# 136747  control   H2az1_ENSMUSG00000037894.14  ...  5.54658e-134   2.24426
# 113941  control   Rack1_ENSMUSG00000020372.16  ...   5.3169e-118   2.10959
# 131836  control   Psma7_ENSMUSG00000027566.16  ...   2.9553e-135   2.06958
# ...         ...                           ...  ...           ...       ...
# 20808       bic    Rn18s_ENSMUSG00000119584.1  ...   9.05836e-17 -0.215964
# 47321       bic    Nrgn_ENSMUSG00000053310.12  ...   8.80545e-11 -0.224694
# 19485       bic   Calm2_ENSMUSG00000036438.15  ...   6.11391e-22 -0.282782
# 10189       bic   Calm1_ENSMUSG00000001175.17  ...   6.13333e-23 -0.317682
# 27553       bic     Cst3_ENSMUSG00000027447.7  ...   3.03957e-55  -0.35506
#
# [247 rows x 5 columns]

# %%
# marker genes that associate with the sugar
condition_mask  = {condition: adata.obs.label.values == condition for condition in conditions}
condition_sugar = {condition: np.log1p(adata.obs.dbco_ipf.values)[cmask] for condition, cmask in condition_mask.items()}
condition_mtx   = {condition: adata.layers['log1p'].toarray()[cmask] for condition, cmask in condition_mask.items()}

rvals = []
rp = []
for k, r in df.iterrows():
  condition = r.group_id
  gene = r.gene
  
  cmask  = condition_mask[condition]
  sugar  = condition_sugar[condition]
  submtx = condition_mtx[condition]

  gene_mask = adata.var.gene_gid.values == gene

  y = nd(submtx[:,gene_mask])

  r,p = pearsonr(sugar,y)
  rvals.append(r**2)
  rp.append(p)

df['r2'] = rvals
df['p_r2'] = rp

# %%
fig, ax = plt.subplots(figsize=(5,5))

fdf = df#.query("group_id == 'tmg'")

x = fdf["es"].values
y = -np.log(fdf['p_corr'].values.astype(float))
r2 = fdf["r2"].values

argsort = np.argsort(r2)
x = x[argsort]
y = y[argsort]
r2 = r2[argsort]

im = ax.scatter(x,y, c = r2, cmap="Reds")

ax.set(**{
    "xlabel": "Effect size",
    "ylabel": "-log(p_corr)"
})

fig.colorbar(im, ax=ax, label="$r^2$")
fig.show()

# %%
df.group_id.value_counts()
# Out:
# control    215
# tmg         20
# bic          6
# bic_tmg      6
# Name: group_id, dtype: int64

# %%
df.query("group_id == 'bic_tmg'")
# Out:
#       group_id                            gene  ...        r2          p_r2
# 73293  bic_tmg   Atp6v0c_ENSMUSG00000024121.14  ...  0.136295  3.796502e-76
# 74388  bic_tmg      Rn18s_ENSMUSG00000119584.1  ...  0.140056  2.329859e-78
# 74735  bic_tmg  Hsp90ab1_ENSMUSG00000023944.15  ...  0.120061  1.047548e-66
# 77238  bic_tmg       Fth1_ENSMUSG00000024661.8  ...  0.120207  8.630839e-67
# 81133  bic_tmg       Cst3_ENSMUSG00000027447.7  ...  0.000036  7.730225e-01
# 90054  bic_tmg      Actb_ENSMUSG00000029580.15  ...  0.089930  1.267121e-49
#
# [6 rows x 7 columns]

# %% [markdown]
# ## Celltypes per condition

# %%
# %%time
dfs = {}
for idx, (label, i) in enumerate(data.items()):
    mat           = i.layers["log1p"].toarray() # this is log1p
    components    = i.obs.index.values
    features      = i.var.gene_gid.values
    assignments   = i.obs.leiden.values


    unique = np.unique(assignments)
    nan_cutoff = 0.9 # of elements in cluster
    corr_method = "bonferroni"


    p_raw, stat, es, nfeat = dexpress(mat, components, features, assignments, nan_cutoff=nan_cutoff)
    p_raw = p_raw/2
    p_corr = correct_pval(p_raw, nfeat, corr_method)

    s = stat

    df = make_table(assignments, features, p_raw, p_corr, es)

    # convert the 0 pvalues to the smallest possible float
    df["p_corr"][df.eval("p_corr == 0").values] = sys.float_info.min
    df = df.query("es > 0").query("p_corr < 0.05")
    df["condition"] = label
    dfs[label] = df
# Out:
# 27-Jan-22 20:46:11 - 1 of 12 assignments: 0
# 27-Jan-22 20:46:11 - 2 of 12 assignments: 1
# 27-Jan-22 20:46:11 - 3 of 12 assignments: 10
# 27-Jan-22 20:46:11 - 4 of 12 assignments: 11
# 27-Jan-22 20:46:11 - 5 of 12 assignments: 2
# 27-Jan-22 20:46:11 - 6 of 12 assignments: 3
# 27-Jan-22 20:46:11 - 7 of 12 assignments: 4
# 27-Jan-22 20:46:11 - 8 of 12 assignments: 5
# 27-Jan-22 20:46:11 - 9 of 12 assignments: 6
# 27-Jan-22 20:46:11 - 10 of 12 assignments: 7
# 27-Jan-22 20:46:11 - 11 of 12 assignments: 8
# 27-Jan-22 20:46:11 - 12 of 12 assignments: 9
# 27-Jan-22 20:46:11 - 1 of 12 assignments: 0
# 27-Jan-22 20:46:11 - 2 of 12 assignments: 1
# 27-Jan-22 20:46:11 - 3 of 12 assignments: 10
# 27-Jan-22 20:46:11 - 4 of 12 assignments: 11
# 27-Jan-22 20:46:11 - 5 of 12 assignments: 2
# 27-Jan-22 20:46:11 - 6 of 12 assignments: 3
# 27-Jan-22 20:46:11 - 7 of 12 assignments: 4
# 27-Jan-22 20:46:12 - 8 of 12 assignments: 5
# 27-Jan-22 20:46:12 - 9 of 12 assignments: 6
# 27-Jan-22 20:46:12 - 10 of 12 assignments: 7
# 27-Jan-22 20:46:12 - 11 of 12 assignments: 8
# 27-Jan-22 20:46:12 - 12 of 12 assignments: 9
# 27-Jan-22 20:46:12 - 1 of 8 assignments: 0
# 27-Jan-22 20:46:12 - 2 of 8 assignments: 1
# 27-Jan-22 20:46:12 - 3 of 8 assignments: 2
# 27-Jan-22 20:46:12 - 4 of 8 assignments: 3
# 27-Jan-22 20:46:12 - 5 of 8 assignments: 4
# 27-Jan-22 20:46:12 - 6 of 8 assignments: 5
# 27-Jan-22 20:46:12 - 7 of 8 assignments: 6
# 27-Jan-22 20:46:12 - 8 of 8 assignments: 7
# 27-Jan-22 20:46:12 - 1 of 8 assignments: 0
# 27-Jan-22 20:46:12 - 2 of 8 assignments: 1
# 27-Jan-22 20:46:12 - 3 of 8 assignments: 2
# 27-Jan-22 20:46:12 - 4 of 8 assignments: 3
# 27-Jan-22 20:46:12 - 5 of 8 assignments: 4
# 27-Jan-22 20:46:12 - 6 of 8 assignments: 5
# 27-Jan-22 20:46:12 - 7 of 8 assignments: 6
# 27-Jan-22 20:46:12 - 8 of 8 assignments: 7
# CPU times: user 935 ms, sys: 85.9 ms, total: 1.02 s
# Wall time: 1.68 s

# %%
adata.obs
# Out:
#                   mtag3_ipf  mtag4_ipf  ...  mahalanobis_2  mahalanobis_3
# barcode                                 ...
# AAACCCAAGTTGGACG      662.0       37.0  ...   9.999011e-01   6.101683e-71
# AAACCCATCGATGCTA      704.0       42.0  ...   9.999943e-01   2.816716e-75
# AAACGAAAGTGGGAAA      964.0      236.0  ...   9.402105e-01   1.381849e-18
# AAACGAACACCCTCTA      897.0      528.0  ...   3.333248e-83   1.075137e-67
# AAACGAACACGGTCTG      977.0      462.0  ...   4.376917e-50   2.140325e-49
# ...                     ...        ...  ...            ...            ...
# TTTGTTGGTGCCTGCA     1202.0      301.0  ...   1.564132e-40   1.540492e-38
# TTTGTTGGTGGTCTCG     1143.0       69.0  ...   3.282225e-44   6.394455e-02
# TTTGTTGTCCCTATTA     1182.0       92.0  ...   5.552994e-31   2.014161e-03
# TTTGTTGTCGATCCCT      906.0      429.0  ...   1.340059e-57   7.229286e-41
# TTTGTTGTCTGTCTCG      961.0       46.0  ...   9.996555e-01   3.658857e-55
#
# [7511 rows x 17 columns]

# %%
clusters = np.unique(df.group_id.values)
# marker genes that associate with the sugar
cluster_mask  = {cluster: adata.obs.leiden.values == cluster for cluster in clusters}
cluster_sugar = {cluster: np.log1p(adata.obs.dbco_ipf.values)[cmask] for cluster, cmask in cluster_mask.items()}
cluster_mtx   = {cluster: adata.layers['log1p'].toarray()[cmask] for cluster, cmask in cluster_mask.items()}

rvals = []
rp = []
for k, r in df.iterrows():
  cluster = r.group_id
  gene = r.gene
  
  cmask  = cluster_mask[cluster]
  sugar  = cluster_sugar[cluster]
  submtx = cluster_mtx[cluster]

  gene_mask = adata.var.gene_gid.values == gene

  y = nd(submtx[:,gene_mask])

  r,p = pearsonr(sugar,y)
  rvals.append(r**2)
  rp.append(p)

df['r2'] = rvals
df['p_r2'] = rp

# %%
markers = pd.concat([i[1] for i in dfs.items()])
markers["condition_group"] = markers["condition"] + "." + markers["group_id"]
table = markers.groupby("condition_group")["gene"].apply(list)

# %%
table
# Out:
# condition_group
# bic.1         [Atp1a2_ENSMUSG00000007097.15, Clu_ENSMUSG0000...
# bic.10        [Fau_ENSMUSG00000038274.14, Cst3_ENSMUSG000000...
# bic.11        [Hba-a1_ENSMUSG00000069919.8, Hba-a2_ENSMUSG00...
# bic.2         [Hnrnpu_ENSMUSG00000039630.11, Ap1s3_ENSMUSG00...
# bic.3         [Ap1s3_ENSMUSG00000054702.15, Itm2c_ENSMUSG000...
# bic.4         [Atp1b1_ENSMUSG00000026576.13, Atp2b1_ENSMUSG0...
# bic.5         [Tsn_ENSMUSG00000026374.15, Hnrnpu_ENSMUSG0000...
# bic.6         [Hnrnpu_ENSMUSG00000039630.11, Ap1s3_ENSMUSG00...
# bic.7         [Ap1s3_ENSMUSG00000054702.15, Cacna1e_ENSMUSG0...
# bic.8                               [Myl6_ENSMUSG00000090841.3]
# bic.9         [H3f3a_ENSMUSG00000060743.13, Ptma_ENSMUSG0000...
# bic_tmg.0     [Atp1a2_ENSMUSG00000007097.15, Clu_ENSMUSG0000...
# bic_tmg.10    [Hnrnpu_ENSMUSG00000039630.11, Ap1s3_ENSMUSG00...
# bic_tmg.11    [Hba-a1_ENSMUSG00000069919.8, Hba-a2_ENSMUSG00...
# bic_tmg.2     [Hnrnpu_ENSMUSG00000039630.11, Ap1s3_ENSMUSG00...
# bic_tmg.3     [Hnrnpu_ENSMUSG00000039630.11, Ap1s3_ENSMUSG00...
# bic_tmg.4     [Hnrnpu_ENSMUSG00000039630.11, Scg2_ENSMUSG000...
# bic_tmg.5     [Ptma_ENSMUSG00000026238.15, Kifap3_ENSMUSG000...
# bic_tmg.6     [Rps29_ENSMUSG00000034892.9, Itm2b_ENSMUSG0000...
# bic_tmg.7     [Ptma_ENSMUSG00000026238.15, Myl6_ENSMUSG00000...
# bic_tmg.8     [Itm2c_ENSMUSG00000026223.16, Atp1b1_ENSMUSG00...
# bic_tmg.9     [Dbi_ENSMUSG00000026385.17, Marcks_ENSMUSG0000...
# control.0     [H3f3a_ENSMUSG00000060743.13, Ptma_ENSMUSG0000...
# control.1     [Desi2_ENSMUSG00000026502.14, Hnrnpu_ENSMUSG00...
# control.2     [Slc39a10_ENSMUSG00000025986.7, Gls_ENSMUSG000...
# control.3     [Desi2_ENSMUSG00000026502.14, Hnrnpu_ENSMUSG00...
# control.6     [Itm2c_ENSMUSG00000026223.16, Kifap3_ENSMUSG00...
# control.7     [Gm29228_ENSMUSG00000101682.2, Gm29668_ENSMUSG...
# tmg.1         [Tsn_ENSMUSG00000026374.15, Hnrnpu_ENSMUSG0000...
# tmg.2         [Hnrnpu_ENSMUSG00000039630.11, Ap1s3_ENSMUSG00...
# tmg.3         [Acsl3_ENSMUSG00000032883.16, Atp1a2_ENSMUSG00...
# tmg.4         [Atp1b1_ENSMUSG00000026576.13, Syt1_ENSMUSG000...
# tmg.6         [Scg2_ENSMUSG00000050711.8, Ap1s3_ENSMUSG00000...
# tmg.7         [Hnrnpu_ENSMUSG00000039630.11, H3f3a_ENSMUSG00...
# Name: gene, dtype: object

# %%
# Attempt to find matchin cell types between conditions by looking at marker gene intersections

# %%
clusters = table.index.values

# %%
itx = np.zeros((len(clusters), len(clusters)))
for i in range(len(clusters)):
  for j in range(len(clusters)):
    itx[i,j] = np.intersect1d(table[clusters[i]], table[clusters[j]]).shape[0]
    # if clusters[i].split('.')[0] != clusters[j].split('.')[0]:
    #   # i and j are not from the same condition
    #   # check size of marker gene list intersection

# %%
np.fill_diagonal(itx, 0)

# %%
plt.matshow(itx)

# %%
itx.argmax(1)
# Out:
# array([11, 28, 13,  6, 28,  3, 28, 28,  6,  3, 23,  0,  6,  2,  6,  6, 28,
#         3, 28,  3,  3,  6, 23, 25, 28, 23,  6, 25,  6, 28,  0,  4, 28, 25])
